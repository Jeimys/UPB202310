# %%
import pandas as pd

# %%
my_data = {
            "student" : ['Yo', 'Tú', 'Ellos'],
            "age" : [19, 20, 20],
            "sex" : ['female', 'male', 'male']
        }

df = pd.DataFrame(my_data)
df
# Out:
#   student  age     sex
# 0      Yo   19  female
# 1      Tú   20    male
# 2   Ellos   20    male

# %%
print(df["age"])
# Out:
# 0    19
# 1    20
# 2    20
# Name: age, dtype: int64

# %%
score = pd.Series([95, 92, 90], name='score')
print(score)
# Out:
# 0    95
# 1    92
# 2    90
# Name: score, dtype: int64

# %%
df.describe()
# Out:
#              age
# count   3.000000
# mean   19.666667
# std     0.577350
# min    19.000000
# 25%    19.500000
# 50%    20.000000
# 75%    20.000000
# max    20.000000

# %%
print(df.describe().std())
# Out:
# age    8.320889
# dtype: float64

# %%
my_data = pd.read_csv('student_data.csv')
my_data
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
my_data.head(8)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1   at_home     other
# 2     GP   F   15       U     LE3       T     1     1   at_home     other
# 3     GP   F   15       U     GT3       T     4     2    health  services
# 4     GP   F   16       U     GT3       T     3     3     other     other
# 5     GP   M   16       U     LE3       T     4     3  services     other
# 6     GP   M   16       U     LE3       T     2     2     other     other
# 7     GP   F   17       U     GT3       A     4     4     other   teacher
#
#    ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0  ...      4        3      4     1     1      3        6   5   6   6
# 1  ...      5        3      3     1     1      3        4   5   5   6
# 2  ...      4        3      2     2     3      3       10   7   8  10
# ...

# %%
my_data.tail(8)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 387     MS   F   19       R     GT3       T     2     3  services     other
# 388     MS   F   18       U     LE3       T     3     1   teacher  services
# 389     MS   F   18       U     GT3       T     1     1     other     other
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 387  ...      5        4      2     1     2      5        0   7   5   0
# 388  ...      4        3      4     1     1      1        0   7   9   8
# ...

# %%
my_data.dtypes
# Out:
# school        object
# sex           object
# age            int64
# address       object
# famsize       object
# Pstatus       object
# Medu           int64
# Fedu           int64
# Mjob          object
# Fjob          object
# reason        object
# guardian      object
# traveltime     int64
# studytime      int64
# failures       int64
# schoolsup     object
# famsup        object
# paid          object
# activities    object
# nursery       object
# higher        object
# internet      object
# romantic      object
# famrel         int64
# freetime       int64
# goout          int64
# Dalc           int64
# Walc           int64
# health         int64
# absences       int64
# G1             int64
# G2             int64
# G3             int64
# dtype: object

# %%
my_data.to_excel('students_data.xlsx', sheet_name='students', index=False)

# %%
my_data_v2 = pd.read_excel('students_data.xlsx', sheet_name='students')

# %%
my_data_v2.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
my_data_v2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
# ...

# %%
age_sex = my_data[['age', 'sex', 'G1']]
print(age_sex.head())
print(type(age_sex))
print(age_sex.shape)
# Out:
#    age sex  G1
# 0   18   F   5
# 1   17   F   5
# 2   15   F   7
# 3   15   F  15
# 4   16   F   6
# <class 'pandas.core.frame.DataFrame'>
# (395, 3)

# %%
below_18 = my_data[my_data['age'] < 18]
below_18.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 1     GP   F   17       U     GT3       T     1     1   at_home     other
# 2     GP   F   15       U     LE3       T     1     1   at_home     other
# 3     GP   F   15       U     GT3       T     4     2    health  services
# 4     GP   F   16       U     GT3       T     3     3     other     other
# 5     GP   M   16       U     LE3       T     4     3  services     other
#
#    ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 1  ...      5        3      3     1     1      3        4   5   5   6
# 2  ...      4        3      2     2     3      3       10   7   8  10
# 3  ...      3        2      2     1     1      5        2  15  14  15
# 4  ...      4        3      2     1     2      5        4   6  10  10
# 5  ...      5        4      2     1     2      5       10  15  15  15
#
# [5 rows x 33 columns]

# %%
age_18_19 = my_data[my_data['age'].isin([18, 19])]
age_18_19.head()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob     Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home  teacher
# 127     GP   F   19       U     GT3       T     0     1   at_home    other
# 128     GP   M   18       R     GT3       T     2     2  services    other
# 150     GP   M   18       U     LE3       T     1     1     other    other
# 153     GP   M   19       U     GT3       T     3     2  services  at_home
#
#      ... famrel freetime  goout  Dalc  Walc health absences G1 G2 G3
# 0    ...      4        3      4     1     1      3        6  5  6  6
# 127  ...      3        4      2     1     1      5        2  7  8  9
# 128  ...      3        3      3     1     2      4        0  7  4  0
# 150  ...      2        3      5     2     5      4        0  6  5  0
# 153  ...      4        5      4     1     1      4        0  5  0  0
#
# [5 rows x 33 columns]

# %%
age_18_19 = my_data[(my_data['age'] == 18) | (my_data['age'] == 19)]
age_18_19.head()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob     Fjob  \
# 127     GP   F   19       U     GT3       T     0     1   at_home    other
# 128     GP   M   18       R     GT3       T     2     2  services    other
# 150     GP   M   18       U     LE3       T     1     1     other    other
# 153     GP   M   19       U     GT3       T     3     2  services  at_home
# 157     GP   F   18       R     GT3       T     1     1   at_home    other
#
#      ... famrel freetime  goout  Dalc  Walc health absences G1 G2  G3
# 127  ...      3        4      2     1     1      5        2  7  8   9
# 128  ...      3        3      3     1     2      4        0  7  4   0
# 150  ...      2        3      5     2     5      4        0  6  5   0
# 153  ...      4        5      4     1     1      4        0  5  0   0
# 157  ...      5        2      5     1     5      4        6  9  8  10
#
# [5 rows x 33 columns]

# %%
age_18_sex = my_data.loc[my_data['age'] == 18, ['sex', 'health']]
age_18_sex.head()
# Out:
#     sex  health
# 0     F       3
# 128   M       4
# 150   M       4
# 157   F       4
# 213   M       5

# %%
my_data.iloc[3:10, 2:5]
# Out:
#    age address famsize
# 3   15       U     GT3
# 4   16       U     GT3
# 5   16       U     LE3
# 6   16       U     LE3
# 7   17       U     GT3
# 8   15       U     LE3
# 9   15       U     GT3

# %%
my_data.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
my_data.iloc[:3, 2] = 12
my_data.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   12       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   12       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   12       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
my_data.loc[:3, 'sex'] = 'M'
my_data.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   M   12       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   M   12       U     GT3       T     1     1  at_home     other  ...
# 2     GP   M   12       U     LE3       T     1     1  at_home     other  ...
# 3     GP   M   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
import numpy as np

x_t = np.arange(1, 11)
x_m = [1.2, 2.3, 2.9, 4.5, 4.8, 6.1, 6.5, 8.1, 9.5, 9.7]
data = {'calculation' : x_t, 'measure' : x_m}
df = pd.DataFrame(data)
df['error'] = abs((df['calculation'] - df['measure'])/df['calculation'])
df['pass'] = df['error'] < 0.05
df.rename(columns={'calculation' : 'theorical'})
df.loc[df['pass'] == True, ['measure', 'error']]
# Out:
#    measure     error
# 2      2.9  0.033333
# 4      4.8  0.040000
# 5      6.1  0.016667
# 7      8.1  0.012500
# 9      9.7  0.030000
