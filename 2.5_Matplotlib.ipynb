# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0, 2 * np.pi, 200)
y = np.sin(x)
fig, ax = plt.subplots()
ax.plot(x, y)
plt.show()

# %%
from matplotlib import pyplot as plt

distance = [2.0, 2.2, 1.8, 2.3, 1.9, 2.0, 2.4]
days = [i for i in range(1, len(distance) + 1)]
plt.plot(days, distance)
plt.show()

# %%
distance_1 = [2.4, 2.2, 1.8, 2.3, 1.9, 2.0, 2.4, 2.3, 2.3]
distance_2 = [2.3, 2.4, 2.0, 1.9, 2.5, 1.8, 2.2]
days_1 = [i for i in range(1, len(distance_1)+ 1)]
days_2 = [i for i in range(1, len(distance_2)+ 1)]
plt.plot(days_1, distance_1)
plt.plot(days_2, distance_2)
plt.show()

# %%
distance_1 = [2.4, 2.2, 1.8, 2.3, 1.9, 2.0, 2.4, 2.3, 2.3]
distance_2 = [2.3, 2.4, 2.0, 1.9, 2.5, 1.8, 2.2]
days_1 = [i for i in range(1, len(distance_1)+ 1)]
days_2 = [i for i in range(1, len(distance_2)+ 1)]
plt.plot(days_1, distance_1, color = 'cyan')
plt.plot(days_2, distance_2, color = '#37e21d')
plt.show()

# %%
distance_1 = [2.4, 2.2, 1.8, 2.3, 1.9, 2.0, 2.4, 2.3, 2.3]
distance_2 = [2.3, 2.4, 2.0, 1.9, 2.5, 1.8, 2.2]
days_1 = [i for i in range(1, len(distance_1)+ 1)]
days_2 = [i for i in range(1, len(distance_2)+ 1)]
plt.plot(days_1, distance_1, color = 'cyan')
plt.plot(days_2, distance_2, color = '#37e21d')
plt.show()

# %%
distance_1 = [2.4, 2.2, 1.8, 2.3, 1.9, 2.0, 2.4, 2.3, 2.3]
distance_2 = [2.3, 2.4, 2.0, 1.9, 2.5, 1.8, 2.2]
days_1 = [i for i in range(1, len(distance_1)+ 1)]
days_2 = [i for i in range(1, len(distance_2)+ 1)]
plt.plot(days_1, distance_1, color = 'cyan', linestyle = '--')
plt.plot(days_2, distance_2, color = '#37e21d', linestyle = ':')
plt.show()

# %%
distance_1 = [2.4, 2.2, 1.8, 2.3, 1.9, 2.0, 2.4, 2.3, 2.3]
distance_2 = [2.3, 2.4, 2.0, 1.9, 2.5, 1.8, 2.2]
days_1 = [i for i in range(1, len(distance_1)+ 1)]
days_2 = [i for i in range(1, len(distance_2)+ 1)]
plt.plot(days_1, distance_1, color = 'cyan', marker = 'o')
plt.plot(days_2, distance_2, color = '#37e21d', marker = 's')
plt.show()

# %%
distance_1 = [2.4, 2.2, 1.8, 2.3, 1.9, 2.0, 2.4, 2.3, 2.3]
distance_2 = [2.3, 2.4, 2.0, 1.9, 2.5, 1.8, 2.2]
days_1 = [i for i in range(1, len(distance_1)+ 1)]
days_2 = [i for i in range(1, len(distance_2)+ 1)]
plt.plot(days_1, distance_1, '-ob') # line style, marker, color 
plt.plot(days_2, distance_2, ':sk')
plt.show()

# %%
distance_1 = [2.4, 2.2, 1.8, 2.3, 1.9, 2.0, 2.4, 2.3, 2.3]
distance_2 = [2.3, 2.4, 2.0, 1.9, 2.5, 1.8, 2.2]
days_1 = [i for i in range(1, len(distance_1)+ 1)]
days_2 = [i for i in range(1, len(distance_2)+ 1)]
plt.plot(days_1, distance_1, color = 'cyan', marker = 'o')
plt.plot(days_2, distance_2, color = '#37e21d', marker = 's')
plt.axis([1, 7, 0, 3]) # (min_x, max_x, min_y, max_y)
plt.show()

# %%
distance_1 = [2.4, 2.2, 1.8, 2.3, 1.9, 2.0, 2.4, 2.3, 2.3]
distance_2 = [2.3, 2.4, 2.0, 1.9, 2.5, 1.8, 2.2]
days_1 = [i for i in range(1, len(distance_1)+ 1)]
days_2 = [i for i in range(1, len(distance_2)+ 1)]
plt.plot(days_1, distance_1, color = 'cyan', marker = 'o')
plt.plot(days_2, distance_2, color = '#37e21d', marker = 's')
plt.axis([1, 7, 0, 3]) # (min_x, max_x, min_y, max_y)
plt.xlabel('Días')
plt.ylabel('Distancia (km)')
plt.title('Distancias recorridas')
plt.show()

# %%
time = [15, 18, 16, 19, 18, 16, 17]
plt.subplot(2, 1, 1)
plt.plot(days, distance)
plt.subplot(2, 1, 2)
plt.plot(days, time)
plt.show()

# %%
time = [15, 18, 16, 19, 18, 16, 17]
plt.subplot(2, 1, 1)
plt.plot(days, distance)
plt.subplot(2, 1, 2)
plt.plot(days, time)
plt.subplots_adjust(hspace = 0.5)
plt.show()

# %%
# falta varias una gráica
